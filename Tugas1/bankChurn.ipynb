# %%
# Mengimpor library yang diperlukan
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('Data_bank_churn.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
X = df.iloc[:, 3:13].values
y = df.iloc[:, 13].values

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
labelencoder = LabelEncoder()
X[:, 2] = labelencoder.fit_transform(X[:, 2])

# %%
columnTransformer = ColumnTransformer([('encoder', OneHotEncoder(), [1])], remainder='passthrough')
X = np.array(columnTransformer.fit_transform(X), dtype = np.float64)

# %%
# Menghilangkan 1 dummy variabel di kolom negara
X = X[:, 1:]
# Membagi data ke test dan training set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Mengimpor library Keras dan turunannya
# Sekarang menggunakan TensorFlow 2.0
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Inisialisasi ANN
MesinKlasifikasi = Sequential()
# Menambah input layer dan hidden layer pertama
MesinKlasifikasi.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))
# Menambah hidden layer kedua
MesinKlasifikasi.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
# Menambah output layer
MesinKlasifikasi.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
# Meenjalankan ANN
MesinKlasifikasi.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
# Fitting ANN ke training set
MesinKlasifikasi.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 800/800 [==============================] - 3s 2ms/step - loss: 0.4865 - accuracy: 0.7954
# Epoch 2/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4303 - accuracy: 0.7960
# Epoch 3/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4246 - accuracy: 0.7960
# Epoch 4/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4197 - accuracy: 0.8084
# Epoch 5/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4169 - accuracy: 0.8257
# Epoch 6/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4143 - accuracy: 0.8300
# Epoch 7/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4127 - accuracy: 0.8314
# Epoch 8/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4103 - accuracy: 0.8321
# Epoch 9/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4076 - accuracy: 0.8328
# Epoch 10/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4056 - accuracy: 0.8344
# Epoch 11/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4041 - accuracy: 0.8355
# Epoch 12/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4027 - accuracy: 0.8340
# Epoch 13/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4012 - accuracy: 0.8334
# Epoch 14/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4004 - accuracy: 0.8338
# Epoch 15/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3996 - accuracy: 0.8357
# Epoch 16/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3989 - accuracy: 0.8351
# Epoch 17/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3983 - accuracy: 0.8349
# Epoch 18/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3978 - accuracy: 0.8342
# Epoch 19/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3973 - accuracy: 0.8350
# Epoch 20/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3976 - accuracy: 0.8346
# Epoch 21/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3968 - accuracy: 0.8344
# Epoch 22/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3964 - accuracy: 0.8335
# Epoch 23/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3964 - accuracy: 0.8355
# Epoch 24/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3961 - accuracy: 0.8360
# Epoch 25/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3957 - accuracy: 0.8356
# Epoch 26/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3958 - accuracy: 0.8363
# Epoch 27/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3958 - accuracy: 0.8359
# Epoch 28/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3958 - accuracy: 0.8371
# Epoch 29/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3952 - accuracy: 0.8351
# Epoch 30/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3951 - accuracy: 0.8332
# Epoch 31/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3951 - accuracy: 0.8350
# Epoch 32/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3959 - accuracy: 0.8356
# Epoch 33/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3953 - accuracy: 0.8340
# Epoch 34/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3951 - accuracy: 0.8374
# Epoch 35/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3954 - accuracy: 0.8345
# Epoch 36/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3948 - accuracy: 0.8366
# Epoch 37/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3953 - accuracy: 0.8354
# Epoch 38/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3949 - accuracy: 0.8350
# Epoch 39/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3944 - accuracy: 0.8359
# Epoch 40/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3945 - accuracy: 0.8346
# Epoch 41/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3944 - accuracy: 0.8350
# Epoch 42/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3946 - accuracy: 0.8365
# Epoch 43/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3946 - accuracy: 0.8353
# Epoch 44/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3945 - accuracy: 0.8355
# Epoch 45/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3940 - accuracy: 0.8361
# Epoch 46/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3941 - accuracy: 0.8354
# Epoch 47/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3941 - accuracy: 0.8350
# Epoch 48/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3940 - accuracy: 0.8344
# Epoch 49/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3942 - accuracy: 0.8350
# Epoch 50/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3943 - accuracy: 0.8367
# Epoch 51/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3936 - accuracy: 0.8365
# Epoch 52/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3941 - accuracy: 0.8363
# Epoch 53/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3947 - accuracy: 0.8353
# Epoch 54/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3940 - accuracy: 0.8365
# Epoch 55/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3942 - accuracy: 0.8351
# Epoch 56/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3943 - accuracy: 0.8359
# Epoch 57/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3938 - accuracy: 0.8363
# Epoch 58/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3944 - accuracy: 0.8361
# Epoch 59/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3942 - accuracy: 0.8350
# Epoch 60/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3932 - accuracy: 0.8346
# Epoch 61/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3935 - accuracy: 0.8366
# Epoch 62/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3938 - accuracy: 0.8361
# Epoch 63/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3940 - accuracy: 0.8365
# Epoch 64/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3939 - accuracy: 0.8364
# Epoch 65/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3940 - accuracy: 0.8360
# Epoch 66/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3934 - accuracy: 0.8344
# Epoch 67/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3941 - accuracy: 0.8361
# Epoch 68/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3940 - accuracy: 0.8341
# Epoch 69/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3930 - accuracy: 0.8356
# Epoch 70/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3936 - accuracy: 0.8331
# Epoch 71/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3939 - accuracy: 0.8369
# Epoch 72/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3938 - accuracy: 0.8363
# Epoch 73/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3936 - accuracy: 0.8361
# Epoch 74/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3936 - accuracy: 0.8354
# Epoch 75/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3935 - accuracy: 0.8379
# Epoch 76/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3938 - accuracy: 0.8360
# Epoch 77/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3931 - accuracy: 0.8349
# Epoch 78/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3935 - accuracy: 0.8346
# Epoch 79/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3938 - accuracy: 0.8354
# Epoch 80/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3933 - accuracy: 0.8347
# Epoch 81/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3935 - accuracy: 0.8354
# Epoch 82/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3931 - accuracy: 0.8350
# Epoch 83/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3937 - accuracy: 0.8351
# Epoch 84/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3930 - accuracy: 0.8345
# Epoch 85/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3939 - accuracy: 0.8338
# Epoch 86/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3939 - accuracy: 0.8349
# Epoch 87/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3934 - accuracy: 0.8357
# Epoch 88/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3935 - accuracy: 0.8349
# Epoch 89/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3929 - accuracy: 0.8345
# Epoch 90/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3937 - accuracy: 0.8356
# Epoch 91/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3928 - accuracy: 0.8366
# Epoch 92/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3933 - accuracy: 0.8359
# Epoch 93/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3933 - accuracy: 0.8361
# Epoch 94/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3929 - accuracy: 0.8379
# Epoch 95/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3933 - accuracy: 0.8370
# Epoch 96/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3934 - accuracy: 0.8353
# Epoch 97/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3933 - accuracy: 0.8365
# Epoch 98/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3931 - accuracy: 0.8353
# Epoch 99/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3938 - accuracy: 0.8365
# Epoch 100/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3929 - accuracy: 0.8354

# %%
# Memprediksi hasil test set
y_pred = MesinKlasifikasi.predict(X_test)
y_pred = (y_pred > 0.5)
# Out:
# 63/63 [==============================] - 0s 1ms/step

# %%
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
# Membuat confusion matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

cm
# Out:
# array([[1550,   45],
#        [ 267,  138]])
